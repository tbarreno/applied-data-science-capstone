# %% [markdown]
# # Initial Data Exploration
#
# This notebook contains an initial glance of the data for this project.
#
# ## About the project
#
# Our goal is to run the **Kaggle**'s competition [PUBG finish placement prediction](https://www.kaggle.com/c/pubg-finish-placement-prediction).
#
# *You are given over 65,000 games' worth of anonymized player data, split into training and testing sets, and asked to predict final placement from final in-game stats and initial player ratings.
#
# What's the best strategy to win in PUBG? Should you sit in one spot and hide your way into victory, or do you need to be the top shot? Let's let the data do the talking!*
#
# So we have the files as **Data assets** on the **IBM Watson Studio** project and this notebook will gather some facts and visualizations from the data.
#
# ## Data access
#
# Let's get the training data set as a `pandas` DataFrame (autogenerated code):

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Id  groupId  matchId  assists  boosts  damageDealt  DBNOs  headshotKills  \
# 0   0       24        0        0       5       247.30      2              0
# 1   1   440875        1        1       0        37.65      1              1
# 2   2   878242        2        0       1        93.73      1              0
# 3   3  1319841        3        0       0        95.88      0              0
# 4   4  1757883        4        0       1         0.00      0              0
#
#    heals  killPlace      ...       revives  rideDistance  roadKills  \
# 0      4         17      ...             1         591.3          0
# 1      0         45      ...             0           0.0          0
# 2      2         54      ...             1           0.0          0
# 3      0         86      ...             0           0.0          0
# 4      1         58      ...             0           0.0          0
#
#    swimDistance  teamKills  vehicleDestroys  walkDistance  weaponsAcquired  \
# ...

# %% [markdown]
# ## Data size

# %%
print("Columns : {}".format(training_data.shape[1]))
print("Rows    : {}".format(training_data.shape[0]))
# Out:
# Columns : 26
# Rows    : 4357336

# %% [markdown]
# ## About the game
#
# *100 players are dropped onto an island empty-handed and must explore, scavenge,
# and eliminate other players until only one is left standing, all while the play zone continues to shrink.*
#
#
# ## Finish placement
#
# The key column on the data set is the `winPlacePerc` that give us the final position of each player,
# normalized between 0 and 1 (1 means that the player wsa the winner of the match).
#
# Let's analyse the relation between the final placement and other colums, looking for significant
# relationships.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(training_data.corr(), 
            annot=True, 
            linewidths=.7, 
            ax=ax,
            fmt='.1f', cmap="RdBu_r")
